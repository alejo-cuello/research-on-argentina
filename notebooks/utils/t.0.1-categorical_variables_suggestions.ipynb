# %% [markdown]
# ChatGPT suggested the following categorical variables to me.

# %% [markdown]
# ### Economic Categories
#
# #### GDP Classification (e.g., Low, Medium, High):
# |         |         |
# |---------|---------|
# | Low GDP | < $500 billion |
# | Medium GDP | $500 billion - $1 trillion |
# | High GDP | > $1 trillion |
#
# #### GDP Growth Rate Categories:
# |         |         |
# |---------|---------|
# | Negative growth | < 0% |
# | Low growth | 0% - 2% |
# | Moderate growth | 2% - 5% |
# | High growth | > 5% |
#
# #### GDP per Capita Classification:
# |         |         |
# |---------|---------|
# | Low income | < $5,000 |
# | Middle income | $5,000 - $20,000 |
# | High income | > $20,000 |
#
# #### Age Group Dominance:
# |         |         |
# |---------|---------|
# | Young population | Population ages 0-14 > 35% |
# | Working-age population | Population ages 15-64 > 60% |
# | Aging population | Population ages 65+ > 20% |
#
# #### Urbanization Level:
# |         |         |
# |---------|---------|
# | Rural-dominated | Urban population < 30% |
# | Mixed | Urban population 30%-70% |
# | Urban-dominated | Urban population > 70% |
#
# #### Population Size Categories:
# |         |         |
# |---------|---------|
# | Small population | < 10 million |
# | Medium population | 10 million - 50 million |
# | Large population | > 50 million |
#
# #### School Enrollment Levels:
# |         |         |
# |---------|---------|
# | Low enrollment | < 50% |
# | Medium enrollment | 50%-80% |
# | High enrollment | > 80% |
#
# #### Education Progression:
# |         |         |
# |---------|---------|
# | Low tertiary enrollment | < 20% |
# | High secondary and tertiary | Secondary > 80%, Tertiary > 50% |
#
# #### Life Expectancy Grouping:
# |         |         |
# |---------|---------|
# | Low life expectancy | < 50 years |
# | Medium life expectancy | 50-70 years |
# | High life expectancy | > 70 years |
#
# #### Fixed Telephone Penetration:
# |         |         |
# |---------|---------|
# | Low | < 10 subscriptions per 100 people |
# | Moderate | 10-50 subscriptions per 100 people |
# | High | > 50 subscriptions per 100 people |
#
# #### Mobile Cellular Penetration:
# |         |         |
# |---------|---------|
# | Low | < 50 subscriptions per 100 people |
# | Moderate | 50-100 subscriptions per 100 people |
# | High | > 100 subscriptions per 100 people |
#
# #### Infant Mortality:
# |         |         |
# |---------|---------|
# | Low mortality | < 10 infant deaths per year |
# | Medium mortality | 10-50 infant deaths per year |
# | High mortality | > 50 infant deaths per year |
#
# #### Refugee Origin and Host Classification:
# |         |         |
# |---------|---------|
# | Refugee origin country | Refugee population by origin > 10,000 |
# | Refugee host country | Refugee population by asylum > 10,000 |
#
# #### Migration Intensity:
# |         |         |
# |---------|---------|
# | Low | < 1% of total population as refugees |
# | Medium | 1%-5% |
# | High | > 5% |
#
# #### Military Dictatorship Era:
# |         |         |
# |---------|---------|
# | Military dictatorship era | 1 if it was a year of military dictatorship, 0 otherwise |
#
# #### Military Rule Intensity:
# |         |         |
# |---------|---------|
# | Short-term | < 5 years under dictatorship |
# | Medium-term | 5-10 years under dictatorship |
# | Long-term | > 10 years under dictatorship |
